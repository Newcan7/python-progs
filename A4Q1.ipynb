# %%
import pandas as pd

#load data into a dataframe object:

#create the dataset
data={
    "Cust_id" : [10052,10093,10015,10072,10061,10015],
    "Order_date" : ["2025-01-01","2025-01-02","2025-01-03","2025-01-04","2025-01-05","2025-01-06"]
    }


df=pd.DataFrame(data)
