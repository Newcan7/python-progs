# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
df=pd.read_csv('company_sales_data.csv')
plt.plot(df.month_number,df.total_profit)
plt.title('Company Title per month')
plt.xlabel('Month_Number')
plt.ylabel('Total_Profit')
plt.show()
# Out:
# Running cells with 'Python 3.14.2' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/ppssp/AppData/Local/Programs/Python/Python314/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
plt.plot(df.month_number,df.total_units,'--ro', linewidth=3)
plt.title('Company Sales data of last year')
plt.xlabel('Month_Number')
plt.ylabel('total_units')
plt.show()

# %%
plt.plot(df.month_number,df.facecream,df.month_number,df.facewash,df.month_number,df.toothpaste,df.month_number,df.bathingsoap,df.month_number,df.shampoo,df.month_number,df.moisturizer,'--o', linewidth=3)
plt.title('Sales data')
plt.xlabel('Month_Number')
plt.ylabel('Sales Unit in number')
plt.show()

# %%
plt.bar(df.month_number,df.facecream, color='pink',width=0.45 )
plt.bar(df.month_number,df.facewash, color='red',width=0.55)
