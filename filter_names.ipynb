# %%
l1=[1,2,3,4,5,6,-7,-6,6,-7,-43,-13]
l2=[1,2,3,4,5,6,-7,-6,6,-7,-43,-13]
l3=[1,2,3,4,5,6,-7,-6,6,-7,-43,-13]
def test_for_negative(x):
    return x>0
t1 = filter(test_for_negative,l1)
t2 = filter(test_for_negative,l2)
t3 = filter(test_for_negative,l3)
l1=list(t1)
l2=set(t2)
l3=tuple(t3)
print(l1)
print(l2)
print(l3)
# Out:
# [1, 2, 3, 4, 5, 6, 6]
# {1, 2, 3, 4, 5, 6}
# (1, 2, 3, 4, 5, 6, 6)
# a
