# %%
a={"key":"value","ram":"code","list":[1,2,9]}
print(a.keys())
print(a.values())
# Out:
# dict_keys(['key', 'ram', 'list'])
# dict_values(['value', 'code', [1, 2, 9]])

# %%
a.items()
# Out:
# dict_items([('key', 'value'), ('ram', 'code'), ('list', [1, 2, 9])])

# %%
a.get('list')
# Out:
# [1, 2, 9]

# %%
s1={1,2,3,4}
s2={3,4,5,6,7,8}
len(s1)
# Out:
# 4

# %%
s2.remove(8)
s2
# Out:
# {3, 4, 5, 6, 7}

# %% [markdown]
# s2.pop()

# %%
s2.pop()
# Out:
# 3

# %%
s2.intersection({6,7,8})
# Out:
# {6, 7}

# %%
s2
# Out:
# {4, 5, 6, 7}

# %%
s2.add(3)
s2
# Out:
# {3, 4, 5, 6, 7}

# %%
s2.add(8)
s2
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
n={'1':"one",'2':"two",'3':"three",'4':"four",'5':"five"}
inp=input("Enter number to check 1-5: ")
n.get(inp)
# Out:
# Enter number to check 1-5:  6

# %%
n=0
s=set()
for i in range (1,9):
    n=int(input("Enter number: "))
    s.add(n)
print(s)
# Out:
# Enter number:  1
# Enter number:  2
# Enter number:  3
# Enter number:  1
# Enter number:  2
# Enter number:  3
# Enter number:  4
# Enter number:  4
# {1, 2, 3, 4}

# %%
a={}
v1=input("Enter language: ")
a["sara"]=v1
v2=input("Enter language: ")
a["tara"]=v2
a
# Out:
# Enter language:  b
# Enter language:  n
# {'sara': 'b', 'tara': 'n'}

# %%
n=1
while n<=3:
    for i in range (1,n+1):
        print("*",end=" ")
    print("\n")
    n=n+1
# Out:
# *
#
# * *
#
# * * *

# %%
n=1
s=3
while n<=3:
    for i in range (1,n+1):
        for j in range (1,s):
            print(" ",end="")
        print("*",end=" ")
        s=s-1
    print("\n")
    n=n+1
# Out:
#   *
#
#  * *
#
# * * *

# %%
for i in range (1,5):
    for j in range (1,i+1):
        if i==1:
            print(1)
        else: 
            print((i-1)
# Out:
#   Cell In[162], line 2
#     for j in range (1,i+1)
#                           ^
# SyntaxError: expected ':'

# %%
n=1
for i in range (1,5):
    for j in range (1,i+1):
        print(n,end=" ")
        n=n+2
    print("\n")
    n=1
# Out:
# 1
#
# 1 3
#
# 1 3 5
#
# 1 3 5 7

# %%
n=int(input("Enter number of rows"))
for i in range (1,n+1):
    if i==1 or i==n:
        for j in range (1,4):
            print("*",end=" ")
    else:
        for j in range (1,3):
            print("*",end="   ")
    print("\n")
# Out:
# Enter number of rows 4
# * * *
#
# *   *
#
# *   *
#
# * * *

# %%
n=1
s=3
while n<=3:
    for i in range (1,n+1):
        for j in range (1,s):
            print(" ",end="")
        print("*",end=" ")
        s=s-1
    print("\n")
    n=n+1
n=1
s=3
while n<=3:
    for i in range (1,n+1):
        for j in range (1,s):
            print(" ",end="")
        print("*",end=" ")
        s=s-1
    print("\n")
    n=n+1

# %%
n=1
s=3
while n<=3:
    for i in range (1,n+1):
        for j in range (1,s):
            print(" ",end="")
        print("*",end=" ")
        s=s-1
    print("\n")
    n=n+1
n=1
s=2
i=2
while n>=2:
    while i>=2:
        print("*",end=" ")
        i=i-2
        n=n-1
        print("\n")
# Out:
#   *
#
#  * *
#
# * * *
