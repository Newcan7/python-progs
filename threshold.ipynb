# %%
l=[1,2,3,4,5,6,-7,-6,6,-7,-43,-13]
def test_for_negative(x,i):
    return x>i
n=int(input("enter threshold"))
t3 = filter(test_for_negative,l,n)
l1=list(t1)
# Out:
# enter threshold 0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3     return x>i
#       4 n=int(input("enter threshold"))
# ----> 5 t3 = filter(test_for_negative,l,n)
#       6 l1=list(t1)
#
# TypeError: filter expected 2 arguments, got 3
