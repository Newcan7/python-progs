# %%
def vowel_check(str):
    vowels="aeiouAEIOU"
    vowelcount=0
    for char in str:
        if char in vowels:
             vowelcount+=1
    return vowelcount
s= input("enter a string")
print(vowel_check(s))
# Out:
# enter a string EEee
# 4

# %%
def vowel_check(str):
    l=[]
    vowels="aeiouAEIOU"
    for char in str:
        if char in vowels and char not in l:
             l.append(char)
    return l
s= input("enter a string")
print(vowel_check(s))
# Out:
# enter a string abcdfgijklmnopqrstuvwxyz
# ['a', 'i', 'o', 'u']
