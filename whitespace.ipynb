# %%
l=["abu","oindri","ribhav","anirudh","","  ",]
vowels="aeiouAEIOU"
def vowels_check(x):
    return x.strip()
t= filter(vowels_check,l)
l1=list(t)
print(l1)
# Out:
# ['abu', 'oindri', 'ribhav', 'anirudh']
